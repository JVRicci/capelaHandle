-- %% [markdown]
-- # [bancoCapela]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [bancoCapela]    Script Date: 11/04/2022 11:55:10 ******/
CREATE DATABASE [bancoCapela]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'bancoCapela', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\bancoCapela.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'bancoCapela_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\bancoCapela_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [bancoCapela] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [bancoCapela].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [bancoCapela] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [bancoCapela] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [bancoCapela] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [bancoCapela] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [bancoCapela] SET ARITHABORT OFF 
GO
ALTER DATABASE [bancoCapela] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [bancoCapela] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [bancoCapela] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [bancoCapela] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [bancoCapela] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [bancoCapela] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [bancoCapela] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [bancoCapela] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [bancoCapela] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [bancoCapela] SET  ENABLE_BROKER 
GO
ALTER DATABASE [bancoCapela] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [bancoCapela] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [bancoCapela] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [bancoCapela] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [bancoCapela] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [bancoCapela] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [bancoCapela] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [bancoCapela] SET RECOVERY FULL 
GO
ALTER DATABASE [bancoCapela] SET  MULTI_USER 
GO
ALTER DATABASE [bancoCapela] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [bancoCapela] SET DB_CHAINING OFF 
GO
ALTER DATABASE [bancoCapela] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [bancoCapela] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [bancoCapela] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [bancoCapela] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'bancoCapela', N'ON'
GO
ALTER DATABASE [bancoCapela] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [jvricci]

-- %%
USE [bancoCapela]
GO

-- %%
/****** Object:  User [jvricci]    Script Date: 11/04/2022 11:55:10 ******/
CREATE USER [jvricci] FOR LOGIN [jvricci] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[catequista]

-- %%
/****** Object:  Table [dbo].[catequista]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[catequista](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idContato] [int] NULL,
	[idEndereco] [int] NULL,
	[idTurma] [int] NULL,
	[nome] [varchar](40) NULL,
	[nascimento] [date] NULL,
	[ativo] [varchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[catequizando]

-- %%
/****** Object:  Table [dbo].[catequizando]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[catequizando](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idContato] [int] NULL,
	[idEndereco] [int] NULL,
	[idResponsavel] [int] NULL,
	[idTurma] [int] NULL,
	[nome] [varchar](40) NULL,
	[nascimento] [date] NULL,
	[faltas] [int] NULL,
	[ativo] [varchar](1) NULL,
	[turma] [varchar](10) NULL,
	[faltaEncontro] [int] NULL,
	[faltaMissa] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[contas]

-- %%
/****** Object:  Table [dbo].[contas]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[contas](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[descricao] [varchar](20) NULL,
	[valor] [real] NULL,
	[categoria] [varchar](10) NULL,
	[fornecedor] [varchar](20) NULL,
	[vencimento] [date] NULL,
	[pagamento] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[contato]

-- %%
/****** Object:  Table [dbo].[contato]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[contato](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[telefone] [varchar](15) NULL,
	[celular] [varchar](15) NULL,
	[email] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[dizimista]

-- %%
/****** Object:  Table [dbo].[dizimista]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[dizimista](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idContato] [int] NOT NULL,
	[idEndereco] [int] NOT NULL,
	[nome] [varchar](50) NULL,
	[cpf] [varchar](50) NULL,
	[nascimento] [date] NULL,
	[casamento] [varchar](10) NULL,
	[estadoCivil] [varchar](20) NULL,
	[conjuge] [varchar](50) NULL,
	[nascConjuge] [date] NULL,
	[ativo] [varchar](1) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[dizimo]

-- %%
/****** Object:  Table [dbo].[dizimo]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[dizimo](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idDizimista] [int] NOT NULL,
	[qtdRecebida] [varchar](10) NULL,
	[dataRecebimento] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[doacao]

-- %%
/****** Object:  Table [dbo].[doacao]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[doacao](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idDoador] [int] NULL,
	[descricao] [varchar](25) NULL,
	[destino] [varchar](40) NULL,
	[dataReceb] [date] NULL,
	[tipoDoacao] [varchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[doador]

-- %%
/****** Object:  Table [dbo].[doador]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[doador](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idContato] [int] NULL,
	[idEndereco] [int] NULL,
	[nome] [varchar](40) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[enderecos]

-- %%
/****** Object:  Table [dbo].[enderecos]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[enderecos](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[logradouro] [varchar](50) NULL,
	[numero] [varchar](10) NULL,
	[bairro] [varchar](40) NULL,
	[cep] [varchar](10) NULL,
	[uf] [varchar](3) NULL,
	[cidade] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[equipe]

-- %%
/****** Object:  Table [dbo].[equipe]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[equipe](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idEvento] [int] NULL,
	[nome] [varchar](40) NULL,
	[funcao] [varchar](40) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[evento]

-- %%
/****** Object:  Table [dbo].[evento]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[evento](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[descricao] [varchar](50) NULL,
	[dataEvento] [date] NULL,
	[responsavel] [varchar](40) NULL,
	[nome] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[faltas]

-- %%
/****** Object:  Table [dbo].[faltas]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[faltas](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idFalta] [int] NULL,
	[faltasCatequese] [int] NULL,
	[faltaMissa] [int] NULL,
	[estado] [varchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[login]

-- %%
/****** Object:  Table [dbo].[login]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[login](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[login] [varchar](20) NULL,
	[senha] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[material]

-- %%
/****** Object:  Table [dbo].[material]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[material](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idEquipe] [int] NULL,
	[idEvento] [int] NULL,
	[descricao] [varchar](30) NULL,
	[qtd] [int] NULL,
	[qtdNecessario] [int] NULL,
	[reponsavel] [varchar](1) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[responsavel]

-- %%
/****** Object:  Table [dbo].[responsavel]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[responsavel](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[responsavel] [varchar](40) NULL,
	[nascRespon] [varchar](40) NULL,
	[estadoCivil] [varchar](10) NULL,
	[tipoCasamento] [varchar](10) NULL,
	[padrinho] [varchar](40) NULL,
	[madrinha] [varchar](40) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[turma]

-- %%
/****** Object:  Table [dbo].[turma]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[turma](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idCatequista] [int] NULL,
	[diaEncontro] [varchar](20) NULL,
	[formacao] [varchar](20) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[usuario]

-- %%
/****** Object:  Table [dbo].[usuario]    Script Date: 11/04/2022 11:55:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[usuario](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nome] [varchar](50) NULL,
	[sexo] [varchar](10) NULL,
	[funcao] [varchar](15) NULL,
	[cpf] [varchar](16) NULL,
	[ativo] [varchar](10) NULL,
	[idlogin] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__catequist__idCon__48CFD27E]

-- %%
ALTER TABLE [dbo].[catequista]  WITH CHECK ADD FOREIGN KEY([idContato])
REFERENCES [dbo].[contato] ([id])
GO

-- %% [markdown]
-- # [FK__catequist__idEnd__49C3F6B7]

-- %%
ALTER TABLE [dbo].[catequista]  WITH CHECK ADD FOREIGN KEY([idEndereco])
REFERENCES [dbo].[enderecos] ([id])
GO

-- %% [markdown]
-- # [FK__catequiza__idCon__45F365D3]

-- %%
ALTER TABLE [dbo].[catequizando]  WITH CHECK ADD FOREIGN KEY([idContato])
REFERENCES [dbo].[contato] ([id])
GO

-- %% [markdown]
-- # [FK__catequiza__idEnd__46E78A0C]

-- %%
ALTER TABLE [dbo].[catequizando]  WITH CHECK ADD FOREIGN KEY([idEndereco])
REFERENCES [dbo].[enderecos] ([id])
GO

-- %% [markdown]
-- # [FK__catequiza__idRes__47DBAE45]

-- %%
ALTER TABLE [dbo].[catequizando]  WITH CHECK ADD FOREIGN KEY([idResponsavel])
REFERENCES [dbo].[responsavel] ([id])
GO

-- %% [markdown]
-- # [FK__dizimista__idCon__74AE54BC]

-- %%
ALTER TABLE [dbo].[dizimista]  WITH CHECK ADD FOREIGN KEY([idContato])
REFERENCES [dbo].[contato] ([id])
GO

-- %% [markdown]
-- # [FK__dizimista__idEnd__75A278F5]

-- %%
ALTER TABLE [dbo].[dizimista]  WITH CHECK ADD FOREIGN KEY([idEndereco])
REFERENCES [dbo].[enderecos] ([id])
GO

-- %% [markdown]
-- # [FK__dizimo__idDizimi__76969D2E]

-- %%
ALTER TABLE [dbo].[dizimo]  WITH CHECK ADD FOREIGN KEY([idDizimista])
REFERENCES [dbo].[dizimista] ([id])
GO

-- %% [markdown]
-- # [idDoador]

-- %%
ALTER TABLE [dbo].[doacao]  WITH CHECK ADD  CONSTRAINT [idDoador] FOREIGN KEY([idDoador])
REFERENCES [dbo].[doador] ([id])
GO
ALTER TABLE [dbo].[doacao] CHECK CONSTRAINT [idDoador]
GO

-- %% [markdown]
-- # [FK__usuario__idlogin__4222D4EF]

-- %%
ALTER TABLE [dbo].[usuario]  WITH CHECK ADD FOREIGN KEY([idlogin])
REFERENCES [dbo].[login] ([id])
GO

-- %% [markdown]
-- # [FK__usuario__idlogin__5AEE82B9]

-- %%
ALTER TABLE [dbo].[usuario]  WITH CHECK ADD FOREIGN KEY([idlogin])
REFERENCES [dbo].[login] ([id])
GO

-- %% [markdown]
-- # [bancoCapela]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [bancoCapela] SET  READ_WRITE 
GO
